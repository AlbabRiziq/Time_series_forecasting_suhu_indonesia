# %% [markdown]
# ## MERAMAL RATA-RATA KENAIKAN SUHU DI INDONESIA MENGGUNAKAN TIME SERIES ANALYTICS

# %% [markdown]
# ######   Peramalan merupakan perkiraan untuk suatu kejadian di waktu yang akan datang. Untuk diperoleh hasil peramalan yang baik perlu tersedia data deret waktu yang memadai dan pemilihan metode peramalan yang tepat sesuai dengan karakteristik dari data deret waktu yang diketahui melalui hasil identifikasi yang dilakukan sebelum dilakukan proses pemodelan dan peramalan. Peramalan yang baik yang salah satunya dicirikan dengan tingkat keakuratan dan kemampuan menirukan perilaku data deret waktu historisnya.

# %% [markdown]
# ###### Analisis deret waktu (time series) adalah analisis yang mempertimbangkan pengaruh waktu secara berurutan. Sedangkan data deret waktu itu sendiri adalah data yang dikumpulkan berdasarkan urutan dan interval waktu tertentu, seperti dalam jam, hari, minggu, bulan, kuartal, semester dan tahun.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style

# %%
df = pd.read_csv("./dataset/dataset.csv")
pd.DataFrame(df)

suhu = pd.DataFrame(df, columns=['Indonesia']).to_numpy().ravel()
tahun = pd.DataFrame(df, columns=['Tahun']).to_numpy().ravel()
panjangData = len(tahun)

# %%
plt.xlabel("Tahun")
plt.ylabel("Suhu(°C)")
plt.plot(tahun, suhu, label="Data suhu")
plt.legend(loc="upper left")

# %% [markdown]
# ### TREND LINE LINEAR REGRESSION

# %% [markdown]
# ###### Pola data trend(Trend Line) merupakan komponen data deret waktu yang menunjukkan peningkatan atau penurunan dalam jangka panjang selama periode waktu yang akan diamati. Pola data tren terjadi jika terdapat kenaikan atau penurunan sekuler jangka panjang dalam data . Pola data tren menunjukkan pergerakan data yang cenderung meningkat dan menurun dalam waktu yang lama. Sehingga pola data tren merupakan kenaikan dan penurunan data yang terjadi dalam waktu yang lama. Untuk pola data trend dapat dilihat pada grafik dibawah

# %%
z = np.polyfit(tahun, suhu, 1)
p = np.poly1d(z)

# %%
# rata_rata = np.mean(suhu)
plt.title("Suhu Indonesia")
plt.xlabel("Tahun")
plt.ylabel("Suhu(°C)")
style.use('seaborn')
plt.scatter(tahun, suhu, label="Data suhu") 
plt.plot(tahun, p(tahun), color='red', label="Trend Line")
plt.legend(loc="upper left")

# %% [markdown]
# ##### Dapat kita lihat di atas, garis berwarna merah menunjukan trend line linear yang cenderung bergerak naik atau biasa dikenal dengan Upward Trend

# %% [markdown]
# # TIME SERIES FORECASTING

# %% [markdown]
# ### Average Forecasting

# %%
df = pd.read_csv("./dataset/dataset_average_forecasting.csv")
pd.DataFrame(df)

suhu2 = pd.DataFrame(df, columns=['Indonesia']).to_numpy().ravel()
tahun2 = pd.DataFrame(df, columns=['Tahun']) 
tahun2_np = tahun2.to_numpy().ravel()
forecast = pd.DataFrame(df, columns=['Forecast']).to_numpy().ravel()
absolute_error = pd.DataFrame(df, columns=['Absolute Error']).to_numpy().ravel()
squared_error = pd.DataFrame(df, columns=['Squared Error']).to_numpy().ravel()

# %%
suhu_rata_rata = np.mean(suhu2)
tahun_forecast = np.array([])
suhu_forecast = np.array([])
tahun_terakhir = tahun2_np[-1]
# print(tahun_terakhir)
n = 1

# %%
print(tahun_forecast)
# Out:
# []

# %%
plt.plot(tahun2, suhu2, label="Data suhu")
plt.scatter(tahun_forecast, suhu_forecast, label="Forecast")
plt.scatter(tahun2, forecast, label="Data suhu")
plt.xlabel("Tahun")
plt.ylabel("Suhu(°C)")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\_libs\index.pyx:142, in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(slice(None, None, None), None)' is an invalid key
#
# ...
