# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("dataset.csv")
pd.DataFrame(df)

suhu = pd.DataFrame(df, columns=['Indonesia']).to_numpy()
tahun = pd.DataFrame(df, columns=['Tahun']).to_numpy()
panjangData = len(tahun)
# pd.DataFrame(df)

# %%
plt.xlabel("Tahun")
plt.ylabel("Suhu(°C)")
plt.plot(tahun, suhu, color='red')

# %%
def linearFunc(x, m):
    y = m * x
    return y

# %%
x_predict = np.array([1968, 2022])
m_awal = 0.01721
y_predict = linearFunc(x_predict, m_awal)

# %%
plt.title("Suhu Indonesia")
plt.xlabel("Tahun")
plt.ylabel("Suhu(°C)")
# plt.axis([1968,2022,25,26.9])
plt.scatter(tahun, suhu) 
# plt.scatter(x_predict, y_predict, color='red')

# %%
print(panjangData)

m_predict = m_awal

for i in range(1, panjangData):
    y_predict = linearFunc(tahun[i], m_predict)
# Out:
# 52
